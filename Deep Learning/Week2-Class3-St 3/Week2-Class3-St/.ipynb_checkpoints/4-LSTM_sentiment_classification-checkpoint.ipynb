# %%
#import relevant packages
from keras.layers import Dense, Activation
from keras.layers.recurrent import SimpleRNN
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers.embeddings import Embedding
from sklearn.model_selection import train_test_split
import numpy as np
import nltk
from nltk.corpus import stopwords
import re
import pandas as pd
# Out:
# Using TensorFlow backend.

# %%
t=pd.read_csv('airline_sentiment.csv')
t.head()
# Out:
#    airline_sentiment                                               text
# 0                  1  @VirginAmerica plus you've added commercials t...
# 1                  0  @VirginAmerica it's really aggressive to blast...
# 2                  0  @VirginAmerica and it's a really big bad thing...
# 3                  0  @VirginAmerica seriously would pay $30 a fligh...
# 4                  1  @VirginAmerica yes, nearly every time I fly VX...

# %%
import nltk
nltk.download('stopwords')
stop = nltk.corpus.stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/gceran/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def preprocess(text):
    text=text.lower()
    text=re.sub('[^0-9a-zA-Z]+',' ',text)
    words = text.split()
    words2=[w for w in words if (w not in stop)]
    #words3=[ps.stem(w) for w in words]
    words4=' '.join(words2)
    return(words4)

# %%
t['text'] = t['text'].apply(preprocess)

# %%
from collections import Counter
counts = Counter()
for i,review in enumerate(t['text']):
    counts.update(review.split())

# %%
words = sorted(counts, key=counts.get, reverse=True)
words[0:10]
# Out:
# ['united',
#  'flight',
#  'usairways',
#  'americanair',
#  'southwestair',
#  'jetblue',
#  'get',
#  'cancelled',
#  'thanks',
#  'service']

# %%
chars = words
nb_chars = len(words)
nb_chars
# Out:
# 12532

# %%
word_to_int = {word: i for i, word in enumerate(words, 1)}
int_to_word = {i: word for i, word in enumerate(words, 1)}

# %%
int_to_word
# Out:
# {1: 'united',
#  2: 'flight',
#  3: 'usairways',
#  4: 'americanair',
#  5: 'southwestair',
#  6: 'jetblue',
#  7: 'get',
#  8: 'cancelled',
#  9: 'thanks',
#  10: 'service',
#  11: '2',
#  12: 'customer',
#  13: 'help',
#  14: 'time',
#  15: 'co',
#  16: 'hours',
#  17: 'http',
#  18: 'hold',
#  19: 'amp',
#  20: 'plane',
#  21: 'us',
#  22: 'thank',
#  23: 'still',
#  24: 'delayed',
#  25: 'one',
#  26: 'flights',
#  27: 'call',
#  28: 'gate',
#  29: 'hour',
#  30: 'flightled',
#  31: 'bag',
#  32: 'back',
#  33: 'would',
#  34: 'got',
#  35: 'late',
#  36: 'phone',
#  37: 'need',
#  38: 'please',
#  39: 'airline',
#  40: '3',
#  41: 'like',
#  42: 'waiting',
#  43: 'today',
#  44: 'virginamerica',
#  45: 'guys',
#  46: '4',
#  47: 'great',
#  48: 'wait',
#  49: 'u',
#  50: 'fly',
#  51: 'never',
#  52: 'day',
#  53: 'trying',
#  54: 'airport',
#  55: 'delay',
#  56: '1',
#  57: 'really',
#  58: 'minutes',
#  59: 'even',
#  60: 'going',
#  61: 'people',
#  62: '5',
#  63: 'last',
#  64: 'way',
#  65: 'bags',
#  66: 'weather',
#  67: 'good',
#  68: 'know',
#  69: 'agent',
#  70: 'home',
#  71: 'make',
#  72: 'told',
#  73: 'luggage',
#  74: 'another',
#  75: 'worst',
#  76: 'go',
#  77: 'flying',
#  78: 'ever',
#  79: 'lost',
#  80: 'seat',
#  81: 'w',
#  82: 'change',
#  83: 'check',
#  84: 'take',
#  85: 'want',
#  86: 'hrs',
#  87: 'crew',
#  88: 'due',
#  89: 'getting',
#  90: 'first',
#  91: 'days',
#  92: 'flighted',
#  93: 'someone',
#  94: 'baggage',
#  95: 'work',
#  96: 'much',
#  97: 'love',
#  98: 'tomorrow',
#  99: 'made',
#  100: 'experience',
#  101: 'response',
#  102: 'let',
#  103: 'see',
#  104: 'could',
#  105: 'new',
#  106: 'ticket',
#  107: 'yes',
#  108: 'two',
#  109: 'sitting',
#  110: 'next',
#  111: 'min',
#  112: 'staff',
#  113: 'customers',
#  114: 'bad',
#  115: 'travel',
#  116: 'email',
#  117: 'better',
#  118: 'line',
#  119: 'seats',
#  120: 'aa',
#  121: 'best',
#  122: 'trip',
#  123: 'number',
#  124: 'problems',
#  125: 'right',
#  126: 'said',
#  127: 'online',
#  128: '10',
#  129: 'since',
#  130: 'stuck',
#  131: 'times',
#  132: '30',
#  133: 'jfk',
#  134: 'long',
#  135: 'flightr',
#  136: 'agents',
#  137: 'already',
#  138: 'nothing',
#  139: 'miss',
#  140: 'boarding',
#  141: 'dm',
#  142: 'well',
#  143: '6',
#  144: 'give',
#  145: 'issue',
#  146: 'passengers',
#  147: 'care',
#  148: 'system',
#  149: 'sure',
#  150: 'website',
#  151: 'connection',
#  152: 'book',
#  153: 'tried',
#  154: 'booked',
#  155: 'hotel',
#  156: 'rude',
#  157: 'left',
#  158: 'find',
#  159: 'sent',
#  160: 'yet',
#  161: 'delays',
#  162: 'night',
#  163: 'called',
#  164: 'tonight',
#  165: 'missed',
#  166: 'refund',
#  167: 'keep',
#  168: 'flt',
#  169: 'airlines',
#  170: 'rebooked',
#  171: 'miles',
#  172: 'says',
#  173: 'put',
#  174: 'mins',
#  175: 'morning',
#  176: 'reservation',
#  177: 'dfw',
#  178: 'issues',
#  179: 'awesome',
#  180: 'info',
#  181: 'think',
#  182: 'hope',
#  183: 'nice',
#  184: 'pay',
#  185: 'air',
#  186: 'working',
#  187: 'booking',
#  188: 'ago',
#  189: 'finally',
#  190: 'tell',
#  191: 'rebook',
#  192: 'use',
#  193: 'lax',
#  194: 'anything',
#  195: 'also',
#  196: 'wifi',
#  197: 'anyone',
#  198: '20',
#  199: 'every',
#  200: 'missing',
#  201: 'appreciate',
#  202: 'week',
#  203: 'free',
#  204: 'done',
#  205: 'business',
#  206: 'helpful',
#  207: 'terrible',
#  208: 'answer',
#  209: 'dca',
#  210: 'phl',
#  211: 'making',
#  212: 'always',
#  213: 'person',
#  214: 'say',
#  215: '8',
#  216: 'sfo',
#  217: 'able',
#  218: 'team',
#  219: 'problem',
#  220: 'fail',
#  221: 'checked',
#  222: 'board',
#  223: 'disappointed',
#  224: 'without',
#  225: 'fix',
#  226: '7',
#  227: 'yesterday',
#  228: 'credit',
#  229: 'delta',
#  230: 'class',
#  231: 'rep',
#  232: 'voucher',
#  233: 'amazing',
#  234: 'speak',
#  235: 'update',
#  236: 'ord',
#  237: 'ridiculous',
#  238: 'almost',
#  239: 'thx',
#  240: 'paid',
#  241: 'understand',
#  242: 'unacceptable',
#  243: 'attendant',
#  244: 'early',
#  245: 'come',
#  246: 'extra',
#  247: 'app',
#  248: 'leave',
#  249: 'hung',
#  250: 'happy',
#  251: 'money',
#  252: 'available',
#  253: 'sorry',
#  254: 'many',
#  255: 'claim',
#  256: 'everyone',
#  257: '15',
#  258: 'look',
#  259: 'pilot',
#  260: 'poor',
#  261: 'ewr',
#  262: 'talk',
#  263: 'employees',
#  264: 'horrible',
#  265: 'stop',
#  266: 'full',
#  267: 'planes',
#  268: 'tarmac',
#  269: '45',
#  270: 'least',
#  271: 'upgrade',
#  272: 'stranded',
#  273: 'company',
#  274: 'clt',
#  275: 'status',
#  276: 'tickets',
#  277: 'job',
#  278: 'took',
#  279: 'ok',
#  280: 'ground',
#  281: 'seriously',
#  282: 'supposed',
#  283: 'gt',
#  284: 'though',
#  285: 'wife',
#  286: 'connecting',
#  287: 'different',
#  288: 'southwest',
#  289: 'bos',
#  290: 'departure',
#  291: 'try',
#  292: 'actually',
#  293: 'site',
#  294: 'calling',
#  295: 'contact',
#  296: 'looking',
#  297: 'instead',
#  298: '1st',
#  299: 'year',
#  300: '40',
#  301: 'family',
#  302: 'found',
#  303: 'ur',
#  304: 'half',
#  305: '50',
#  306: 'landed',
#  307: 'open',
#  308: 'taking',
#  309: 'received',
#  310: 'oh',
#  311: 'vacation',
#  312: 'frustrated',
#  313: 'three',
#  314: 'weeks',
#  315: 'food',
#  316: 'follow',
#  317: 'wrong',
#  318: 'boston',
#  319: 'hr',
#  320: 'gave',
#  321: 'via',
#  322: 'earlier',
#  323: '9',
#  324: 'twitter',
#  325: 'something',
#  326: 'bc',
#  327: 'far',
#  328: 'big',
#  329: 'mechanical',
#  330: 'broken',
#  331: '24',
#  332: 'denver',
#  333: 'reason',
#  334: '11',
#  335: 'reply',
#  336: 'desk',
#  337: 'send',
#  338: 'twice',
#  339: 'away',
#  340: 'direct',
#  341: 'b',
#  342: 'worse',
#  343: 'past',
#  344: 'point',
#  345: 'maybe',
#  346: 'pass',
#  347: 'enough',
#  348: 'sit',
#  349: 'needs',
#  350: 'might',
#  351: 'dallas',
#  352: 'makes',
#  353: 'old',
#  354: 'asked',
#  355: 'changed',
#  356: 'tweet',
#  357: 'name',
#  358: 'option',
#  359: 'went',
#  360: 'charge',
#  361: '25',
#  362: 'chicago',
#  363: 'less',
#  364: 'message',
#  365: 'runway',
#  366: 'little',
#  367: 'thing',
#  368: 'nyc',
#  369: 'san',
#  370: '800',
#  371: 'stay',
#  372: 'things',
#  373: 'waited',
#  374: 'lot',
#  375: 'saying',
#  376: 'leaving',
#  377: 'awful',
#  378: '200',
#  379: 'cool',
#  380: 'return',
#  381: 'around',
#  382: 'account',
#  383: 'seems',
#  384: 'fee',
#  385: 'lack',
#  386: 'american',
#  387: 'frustrating',
#  388: 'reservations',
#  389: 'hey',
#  390: 'hard',
#  391: 'longer',
#  392: 'sucks',
#  393: 'houston',
#  394: 'else',
#  395: 'telling',
#  396: 'real',
#  397: 'phx',
#  398: 'card',
#  399: 'car',
#  400: 'charlotte',
#  401: 'show',
#  402: 'destination',
#  403: 'given',
#  404: 'airways',
#  405: 'arrived',
#  406: 'c',
#  407: 'together',
#  408: 'looks',
#  409: 'calls',
#  410: 'guess',
#  411: 'attendants',
#  412: 'feel',
#  413: 'sat',
#  414: 'minute',
#  415: 'snow',
#  416: 'coming',
#  417: 'cust',
#  418: 'thru',
#  419: 'maintenance',
#  420: 'start',
#  421: 'counting',
#  422: 'vegas',
#  423: 'link',
#  424: 'pls',
#  425: 'joke',
#  426: '12',
#  427: 'iah',
#  428: 'fleet',
#  429: 'heard',
#  430: 'fll',
#  431: 'may',
#  432: 'member',
#  433: '100',
#  434: 'policy',
#  435: 'error',
#  436: 'landing',
#  437: 'suck',
#  438: 'row',
#  439: 'loyal',
#  440: 'life',
#  441: 'den',
#  442: 'happened',
#  443: 'options',
#  444: 'add',
#  445: 'philly',
#  446: 'apology',
#  447: 'spent',
#  448: 'reflight',
#  449: 'information',
#  450: 'plus',
#  451: 'everything',
#  452: 'human',
#  453: 'scheduled',
#  454: 'offer',
#  455: 'cost',
#  456: 'newark',
#  457: 'glad',
#  458: 'using',
#  459: 'soon',
#  460: 'believe',
#  461: 'hear',
#  462: 'communication',
#  463: 'reach',
#  464: 'busy',
#  465: 'iad',
#  466: 'end',
#  467: 'lga',
#  468: 'im',
#  469: 'assistance',
#  470: 'cannot',
#  471: 'ua',
#  472: 'terminal',
#  473: 'usair',
#  474: 'fleek',
#  475: 'lose',
#  476: 'quick',
#  477: 'boarded',
#  478: 'arrive',
#  479: 'needed',
#  480: 'changes',
#  481: 'swa',
#  482: 'wow',
#  483: 'guy',
#  484: 'room',
#  485: 'complaint',
#  486: 'jet',
#  487: 'expect',
#  488: 'flew',
#  489: 'las',
#  490: 'paying',
#  491: 'kids',
#  492: 'helping',
#  493: 'passenger',
#  494: 'entire',
#  495: 'computer',
#  496: 'unitedairlines',
#  497: 'counter',
#  498: 'used',
#  499: 'pick',
#  500: 'miami',
#  501: 'mean',
#  502: 'confirmation',
#  503: 'forward',
#  504: 'city',
#  505: 'wanted',
#  506: 'whole',
#  507: 'sw',
#  508: 'blue',
#  509: '2nd',
#  510: 'process',
#  511: 'dc',
#  512: 'wtf',
#  513: 'hoping',
#  514: 'empty',
#  515: 'non',
#  516: 'form',
#  517: 'idea',
#  518: 'friend',
#  519: 'automated',
#  520: 'holding',
#  521: 'pretty',
#  522: 'beyond',
#  523: 'tv',
#  524: 'checking',
#  525: 'run',
#  526: 'bwi',
#  527: 'situation',
#  528: 'deal',
#  529: 'fine',
#  530: 'rt',
#  531: 'respond',
#  532: 'pilots',
#  533: 'place',
#  534: 'years',
#  535: 'chance',
#  536: 'request',
#  537: 'thought',
#  538: 'flighting',
#  539: 'rather',
#  540: 'sleep',
#  541: 'standby',
#  542: 'fault',
#  543: 'customerservice',
#  544: 'cant',
#  545: 'points',
#  546: 'wish',
#  547: 'supervisor',
#  548: 'upset',
#  549: 'yeah',
#  550: 'case',
#  551: 'taken',
#  552: 'mco',
#  553: 'moved',
#  554: 'completely',
#  555: 'buy',
#  556: 'offered',
#  557: 'handle',
#  558: 'confirmed',
#  559: 'treat',
#  560: 'monday',
#  561: 'second',
#  562: 'ask',
#  563: 'updates',
#  564: 'traveling',
#  565: 'top',
#  566: 'employee',
#  567: 'disconnected',
#  568: 'hi',
#  569: 'support',
#  570: 'easy',
#  571: 'reschedule',
#  572: 'apparently',
#  573: 'group',
#  574: 'international',
#  575: 'compensation',
#  576: 'happen',
#  577: 'delivered',
#  578: 'sunday',
#  579: 'hate',
#  580: 'lt',
#  581: 'mia',
#  582: 'either',
#  583: 'world',
#  584: 'provide',
#  585: 'question',
#  586: 'possible',
#  587: 'carry',
#  588: 'connections',
#  589: 'drive',
#  590: 'months',
#  591: 'seem',
#  592: 'asking',
#  593: 'zero',
#  594: 'lol',
#  595: 'appreciated',
#  596: 'la',
#  597: 'friendly',
#  598: 'month',
#  599: 'super',
#  600: 'sad',
#  601: 'checkin',
#  602: 'charged',
#  603: 'club',
#  604: 'helped',
#  605: 'fees',
#  606: 'platinum',
#  607: 'figure',
#  608: 'fact',
#  609: 'leg',
#  610: 'hopefully',
#  611: 'gets',
#  612: 'flightlations',
#  613: 'live',
#  614: 'kind',
#  615: 'four',
#  616: 'bought',
#  617: 'flightlation',
#  618: 'high',
#  619: 'price',
#  620: 'future',
#  621: 'reps',
#  622: 'despite',
#  623: 'atl',
#  624: 'happens',
#  625: 'extremely',
#  626: 'clothes',
#  627: 'means',
#  628: 'list',
#  629: 'huge',
#  630: 'crazy',
#  631: 'losing',
#  632: 'destinationdragons',
#  633: 'answering',
#  634: 'f',
#  635: 'front',
#  636: 'tsa',
#  637: 'ny',
#  638: 'fun',
#  639: 'inconvenience',
#  640: 'https',
#  641: 'several',
#  642: 'shit',
#  643: 'answers',
#  644: 'gives',
#  645: 'sending',
#  646: 'seen',
#  647: 'media',
#  648: 'water',
#  649: 'rock',
#  650: 'asap',
#  651: 'giving',
#  652: 'rescheduled',
#  653: 'came',
#  654: 'safety',
#  655: 'purchase',
#  656: 'spoke',
#  657: 'address',
#  658: 'luck',
#  659: 'details',
#  660: 'pm',
#  661: 'fixed',
#  662: 'unable',
#  663: 'phones',
#  664: 'sense',
#  665: 'multiple',
#  666: 'switch',
#  667: 'dont',
#  668: 'friends',
#  669: 'lots',
#  670: 'flown',
#  671: 'gold',
#  672: 'gonna',
#  673: 'luv',
#  674: '1k',
#  675: 'part',
#  676: 'held',
#  677: 'kudos',
#  678: 'load',
#  679: 'arrival',
#  680: 'priority',
#  681: 'treated',
#  682: 'hang',
#  683: 'relations',
#  684: 'award',
#  685: 'must',
#  686: 'totally',
#  687: 'keeps',
#  688: 'spend',
#  689: 'report',
#  690: 'austin',
#  691: 'set',
#  692: 'excellent',
#  693: 'plans',
#  694: 'storm',
#  695: 'complete',
#  696: 'wonderful',
#  697: 'aircraft',
#  698: 'members',
#  699: 'ready',
#  700: 'nope',
#  701: 'original',
#  702: 'ppl',
#  703: 'lines',
#  704: 'knew',
#  705: 'tuesday',
#  706: 'country',
#  707: 'americanairlines',
#  708: '000',
#  709: 'cabin',
#  710: 'probably',
#  711: 'fare',
#  712: 'space',
#  713: 'read',
#  714: 'date',
#  715: 'overnight',
#  716: 'matter',
#  717: 'okay',
#  718: 'neveragain',
#  719: 'responding',
#  720: 'control',
#  721: 'dealing',
#  722: '1hr',
#  723: 'attitude',
#  724: 'allow',
#  725: 'letter',
#  726: 'gone',
#  727: 'cause',
#  728: 'layover',
#  729: 'running',
#  730: 'folks',
#  731: 'r',
#  732: 'husband',
#  733: 'forced',
#  734: 'word',
#  735: 'explain',
#  736: 'vouchers',
#  737: 'goes',
#  738: 'ice',
#  739: 'literally',
#  740: 'complaints',
#  741: 'mess',
#  742: 'excited',
#  743: 'middle',
#  744: 'correct',
#  745: 'kept',
#  746: 'land',
#  747: 'absolutely',
#  748: 'small',
#  749: 'currently',
#  750: 'arriving',
#  751: 'record',
#  752: 'mine',
#  753: 'knows',
#  754: 'however',
#  755: 'unfortunately',
#  756: 'usairwaysfail',
#  757: 'door',
#  758: '90',
#  759: 'choice',
#  760: 'plan',
#  761: 'bring',
#  762: 'hangs',
#  763: 'yall',
#  764: 'useless',
#  765: '2015',
#  766: 'takes',
#  767: '35',
#  768: 'closed',
#  769: 'access',
#  770: 'center',
#  771: 'learn',
#  772: 'worked',
#  773: 'services',
#  774: 'note',
#  775: 'lounge',
#  776: 'ruined',
#  777: 'bs',
#  778: 'tag',
#  779: 'letting',
#  780: 'worth',
#  781: '75',
#  782: 'failed',
#  783: 'nashville',
#  784: 'none',
#  785: 'explanation',
#  786: 'orlando',
#  787: 'area',
#  788: 'bna',
#  789: 'haha',
#  790: 'cold',
#  791: 'birthday',
#  792: 'sign',
#  793: 'mind',
#  794: 'ride',
#  795: 'anyway',
#  796: 'btw',
#  797: 'web',
#  798: 'drink',
#  799: 'shows',
#  800: 'window',
#  801: 'happening',
#  802: 'mileage',
#  803: 'course',
#  804: 'svc',
#  805: 'overhead',
#  806: 'unhelpful',
#  807: 'caused',
#  808: 'drop',
#  809: 'unhappy',
#  810: 'resolved',
#  811: 'rdu',
#  812: 'changing',
#  813: 'volume',
#  814: '3rd',
#  815: 'entertainment',
#  816: 'schedule',
#  817: 'flyer',
#  818: 'page',
#  819: 'lady',
#  820: 'friday',
#  821: 'filed',
#  822: 'behind',
#  823: 'story',
#  824: 'feb',
#  825: 'dropped',
#  826: 'tix',
#  827: 'yr',
#  828: 'short',
#  829: 'started',
#  830: 'others',
#  831: 'total',
#  832: 'anymore',
#  833: '22',
#  834: 'mom',
#  835: 'works',
#  836: 'captain',
#  837: 'tired',
#  838: 'move',
#  839: 'major',
#  840: 'n',
#  841: '2hrs',
#  842: 'airplane',
#  843: 'daughter',
#  844: 'screwed',
#  845: 'talked',
#  846: 'cover',
#  847: 'fucking',
#  848: 'except',
#  849: 'social',
#  850: 'bumped',
#  851: 'safe',
#  852: 'acceptable',
#  853: 'worries',
#  854: 'select',
#  855: 'trouble',
#  856: 'absolute',
#  857: 'notification',
#  858: 'stuff',
#  859: 'route',
#  860: 'charging',
#  861: 'meeting',
#  862: 'nightmare',
#  863: 'man',
#  864: 'anywhere',
#  865: 'connect',
#  866: 'pathetic',
#  867: 'flightd',
#  868: 'airports',
#  869: 'keeping',
#  870: 'failure',
#  871: 'takeoff',
#  872: 'catch',
#  873: 'damn',
#  874: 'single',
#  875: 'cs',
#  876: 'post',
#  877: 'angry',
#  878: 'badservice',
#  879: 'showing',
#  880: 'evening',
#  881: 'kidding',
#  882: 'allowed',
#  883: 'true',
#  884: '60',
#  885: 'meal',
#  886: 'plz',
#  887: 'close',
#  888: 'philadelphia',
#  889: 'dividend',
#  890: 'virgin',
#  891: 'mobile',
#  892: 'depart',
#  893: 'pre',
#  894: 'dulles',
#  895: 'watch',
#  896: 'bit',
#  897: 'round',
#  898: 'bank',
#  899: 'submitted',
#  900: 'e',
#  901: 'resolve',
#  902: 'moving',
#  903: '19',
#  904: 'talking',
#  905: 'train',
#  906: 'onto',
#  907: 'share',
#  908: 'tells',
#  909: 'confirm',
#  910: 'denied',
#  911: 'feedback',
#  912: 'hell',
#  913: 'onboard',
#  914: 'bother',
#  915: 'excuse',
#  916: '21',
#  917: 'compensate',
#  918: 'refused',
#  919: 'hanging',
#  920: 'handled',
#  921: 'especially',
#  922: 'unbelievable',
#  923: 'fantastic',
#  924: 'seating',
#  925: 'planned',
#  926: 'video',
#  927: 'fuck',
#  928: 'itinerary',
#  929: 'suitcase',
#  930: 'emails',
#  931: 'loved',
#  932: 'slow',
#  933: 'waste',
#  934: 'experienced',
#  935: 'cut',
#  936: 'auto',
#  937: 'transfer',
#  938: 'security',
#  939: 'equipment',
#  940: 'standing',
#  941: 'switched',
#  942: 'file',
#  943: 'impossible',
#  944: 'updated',
#  945: 'wasted',
#  946: 'weekend',
#  947: 'power',
#  948: 'id',
#  949: 'merger',
#  950: 'sick',
#  951: 'listening',
#  952: 'screw',
#  953: 'impressed',
#  954: 'answered',
#  955: 'baby',
#  956: 'god',
#  957: 'hire',
#  958: 'lies',
#  959: 'hello',
#  960: 'clearly',
#  961: 'companion',
#  962: 'inflight',
#  963: 'disappointing',
#  964: 'text',
#  965: 'oscars',
#  966: '14',
#  967: 'notice',
#  968: 'mention',
#  969: 'afternoon',
#  970: 'frequent',
#  971: 'funny',
#  972: 'lovely',
#  973: 'code',
#  974: 'mail',
#  975: 'preferred',
#  976: 'badcustomerservice',
#  977: 'flightling',
#  978: 'usually',
#  979: 'definitely',
#  980: 'followed',
#  981: 'offering',
#  982: 'phoenix',
#  983: 'gates',
#  984: 'office',
#  985: 'tho',
#  986: 'difference',
#  987: 'cc',
#  988: '23',
#  989: 'de',
#  990: 'per',
#  991: 'following',
#  992: 'catering',
#  993: 'conf',
#  994: 'turned',
#  995: '16',
#  996: 'warm',
#  997: 'funeral',
#  998: 'expensive',
#  999: 'news',
#  1000: 'traveler',
#  ...}

# %%
mapped_reviews = []
for review in t['text']:
    mapped_reviews.append([word_to_int[word] for word in review.split()])

# %%
print('Original text:',t.loc[0]['text'])
print('Mapped text:',mapped_reviews[0])
# Out:
# Original text: virginamerica plus added commercials experience tacky
# Mapped text: [44, 450, 1142, 2233, 100, 5429]

# %%
t.loc[0:1]['text']
# Out:
# 0    virginamerica plus added commercials experienc...
# 1    virginamerica really aggressive blast obnoxiou...
# Name: text, dtype: object

# %%
mapped_reviews[0:2]
# Out:
# [[44, 450, 1142, 2233, 100, 5429],
#  [44, 57, 3036, 3845, 3846, 815, 3037, 3847, 19, 366, 2234]]

# %%
length_sent = []
for i in range(len(mapped_reviews)):
  length_sent.append(len(mapped_reviews[i]))
max(length_sent)
# Out:
# 26

# %%
sequence_length = max(length_sent)
from keras.preprocessing.sequence import pad_sequences
X = pad_sequences(maxlen=sequence_length, sequences=mapped_reviews, padding="post", value=0)

# %%
X.shape
# Out:
# (11541, 26)

# %%
y=t['airline_sentiment'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=10)
y_train2 = to_categorical(y_train)
y_test2 = to_categorical(y_test)

# %% [markdown]
# # Sentiment classification using LSTM

# %%
from keras.layers import LSTM

# %%
embedding_vecor_length=32
max_review_length=26
model = Sequential()
model.add(Embedding(input_dim=12533, output_dim=32, input_length = 26))
model.add(LSTM(40, return_sequences=False))
model.add(Dense(2, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 26, 32)            401056
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 40)                11680
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 82
# =================================================================
# Total params: 412,818
# Trainable params: 412,818
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
W = model.layers[1].get_weights()[0]
U = model.layers[1].get_weights()[1]
b = model.layers[1].get_weights()[2]
print(W.shape,U.shape,b.shape)
# Out:
# (32, 160) (40, 160) (160,)

# %%
units = 40
W_i = W[:, :units]
W_f = W[:, units: units * 2]
W_c = W[:, units * 2: units * 3]
W_o = W[:, units * 3:]

U_i = U[:, :units]
U_f = U[:, units: units * 2]
U_c = U[:, units * 2: units * 3]
U_o = U[:, units * 3:]

b_i = b[:units]
b_f = b[units: units * 2]
b_c = b[units * 2: units * 3]
b_o = b[units * 3:]

# %%
W.shape
# Out:
# (32, 160)

# %%
73*160
# Out:
# 11680

# %%
history = model.fit(X_train, y_train2, validation_data=(X_test, y_test2), epochs=10, batch_size=32)
# Out:
# /Users/gceran/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 8078 samples, validate on 3463 samples
# Epoch 1/10
# 8078/8078 [==============================] - 7s 911us/step - loss: 0.3861 - accuracy: 0.8474 - val_loss: 0.2229 - val_accuracy: 0.9090
# Epoch 2/10
# 8078/8078 [==============================] - 7s 829us/step - loss: 0.1596 - accuracy: 0.9438 - val_loss: 0.2017 - val_accuracy: 0.9180
# Epoch 3/10
# 8078/8078 [==============================] - 8s 974us/step - loss: 0.0848 - accuracy: 0.9712 - val_loss: 0.2334 - val_accuracy: 0.9165
# Epoch 4/10
# 8078/8078 [==============================] - 8s 1ms/step - loss: 0.0481 - accuracy: 0.9843 - val_loss: 0.2892 - val_accuracy: 0.9105
# Epoch 5/10
# 8078/8078 [==============================] - 7s 873us/step - loss: 0.0296 - accuracy: 0.9911 - val_loss: 0.3916 - val_accuracy: 0.9128
# Epoch 6/10
# 8078/8078 [==============================] - 7s 875us/step - loss: 0.0223 - accuracy: 0.9946 - val_loss: 0.4063 - val_accuracy: 0.9116
# Epoch 7/10
# 8078/8078 [==============================] - 7s 879us/step - loss: 0.0169 - accuracy: 0.9955 - val_loss: 0.5228 - val_accuracy: 0.9119
# Epoch 8/10
# 8078/8078 [==============================] - 7s 884us/step - loss: 0.0181 - accuracy: 0.9953 - val_loss: 0.4481 - val_accuracy: 0.9111
# Epoch 9/10
# 8078/8078 [==============================] - 7s 888us/step - loss: 0.0124 - accuracy: 0.9967 - val_loss: 0.4881 - val_accuracy: 0.9096
# Epoch 10/10
# 8078/8078 [==============================] - 7s 892us/step - loss: 0.0109 - accuracy: 0.9969 - val_loss: 0.4908 - val_accuracy: 0.9079

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(val_loss_values) + 1)
import matplotlib.ticker as mtick
plt.subplot(211)
plt.plot(epochs, history.history['loss'], 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Test loss')
plt.title('Training and test loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(False)
plt.show()
plt.subplot(212)
plt.plot(epochs, history.history['accuracy'], 'bo', label='Training accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Test accuracy')
plt.title('Training and test accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.gca().set_yticklabels(['{:.0f}%'.format(x*100) for x in plt.gca().get_yticks()]) 
plt.legend()
plt.grid(False)
plt.show()
